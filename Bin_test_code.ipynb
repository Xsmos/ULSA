# %%
from ULSA.sky_map.produce_absorbed_sky_map import absorption_JRZ
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

def produce_sky_map():
    sky_map_list = []
    nside = 2 ** 2 # 2 ** 6
    dist = 50.

    for v in range(1,3,1): # (1,10,1)
        f = absorption_JRZ(v=v, nside=nside, index_type='constant_index', distance=dist,
                           using_raw_diffuse=False, using_default_params=False, input_spectral_index=None,
                           critical_dis=False, output_absorp_free_skymap=False)
        sky_map_list.append(f.mpi())

    return sky_map_list
# Out:
# Version-0.9,separate free-free and synchrotron emission.

# %%
sky_map_list = produce_sky_map()
# Out:
# in rank0
# rest_number 192
# rest_number 191
# rest_number 190
# rest_number 189
# rest_number 188
# rest_number 187
# rest_number 186
# rest_number 185
# rest_number 184
# rest_number 183
# rest_number 182
# rest_number 181
# rest_number 180
# rest_number 179
# rest_number 178
# rest_number 177
# rest_number 176
# rest_number 175
# rest_number 174
# rest_number 173
# rest_number 172
# rest_number 171
# rest_number 170
# rest_number 169
# rest_number 168
# rest_number 167
# rest_number 166
# rest_number 165
# rest_number 164
# rest_number 163
# rest_number 162
# rest_number 161
# rest_number 160
# rest_number 159
# rest_number 158
# rest_number 157
# rest_number 156
# rest_number 155
# rest_number 154
# rest_number 153
# rest_number 152
# rest_number 151
# rest_number 150
# rest_number 149
# rest_number 148
# rest_number 147
# rest_number 146
# rest_number 145
# rest_number 144
# rest_number 143
# rest_number 142
# rest_number 141
# rest_number 140
# rest_number 139
# rest_number 138
# rest_number 137
# rest_number 136
# rest_number 135
# rest_number 134
# rest_number 133
# rest_number 132
# rest_number 131
# rest_number 130
# rest_number 129
# rest_number 128
# rest_number 127
# rest_number 126
# rest_number 125
# rest_number 124
# rest_number 123
# rest_number 122
# rest_number 121
# rest_number 120
# rest_number 119
# rest_number 118
# rest_number 117
# rest_number 116
# rest_number 115
# rest_number 114
# rest_number 113
# rest_number 112
# rest_number 111
# rest_number 110
# rest_number 109
# rest_number 108
# rest_number 107
# rest_number 106
# rest_number 105
# rest_number 104
# rest_number 103
# rest_number 102
# rest_number 101
# rest_number 100
# rest_number 99
# rest_number 98
# rest_number 97
# rest_number 96
# rest_number 95
# rest_number 94
# rest_number 93
# rest_number 92
# rest_number 91
# rest_number 90
# rest_number 89
# rest_number 88
# rest_number 87
# rest_number 86
# rest_number 85
# rest_number 84
# rest_number 83
# rest_number 82
# rest_number 81
# rest_number 80
# rest_number 79
# rest_number 78
# rest_number 77
# rest_number 76
# rest_number 75
# rest_number 74
# rest_number 73
# rest_number 72
# rest_number 71
# rest_number 70
# rest_number 69
# rest_number 68
# rest_number 67
# rest_number 66
# rest_number 65
# rest_number 64
# rest_number 63
# rest_number 62
# rest_number 61
# rest_number 60
# rest_number 59
# rest_number 58
# rest_number 57
# rest_number 56
# rest_number 55
# rest_number 54
# rest_number 53
# rest_number 52
# rest_number 51
# rest_number 50
# rest_number 49
# rest_number 48
# rest_number 47
# rest_number 46
# rest_number 45
# rest_number 44
# rest_number 43
# rest_number 42
# rest_number 41
# rest_number 40
# rest_number 39
# rest_number 38
# rest_number 37
# rest_number 36
# rest_number 35
# rest_number 34
# rest_number 33
# rest_number 32
# rest_number 31
# rest_number 30
# rest_number 29
# rest_number 28
# rest_number 27
# rest_number 26
# rest_number 25
# rest_number 24
# rest_number 23
# rest_number 22
# rest_number 21
# rest_number 20
# rest_number 19
# rest_number 18
# rest_number 17
# rest_number 16
# rest_number 15
# rest_number 14
# rest_number 13
# rest_number 12
# rest_number 11
# rest_number 10
# rest_number 9
# rest_number 8
# rest_number 7
# rest_number 6
# rest_number 5
# rest_number 4
# rest_number 3
# rest_number 2
# rest_number 1
# in the beginning
# left number of pixel 100
# left number of pixel 10
# end, good job!, you are the best
# in rank0
# rest_number 192
# rest_number 191
# rest_number 190
# rest_number 189
# rest_number 188
# rest_number 187
# rest_number 186
# rest_number 185
# rest_number 184
# rest_number 183
# rest_number 182
# rest_number 181
# rest_number 180
# rest_number 179
# rest_number 178
# rest_number 177
# rest_number 176
# rest_number 175
# rest_number 174
# rest_number 173
# rest_number 172
# rest_number 171
# rest_number 170
# rest_number 169
# rest_number 168
# rest_number 167
# rest_number 166
# rest_number 165
# rest_number 164
# rest_number 163
# rest_number 162
# rest_number 161
# rest_number 160
# rest_number 159
# rest_number 158
# rest_number 157
# rest_number 156
# rest_number 155
# rest_number 154
# rest_number 153
# rest_number 152
# rest_number 151
# rest_number 150
# rest_number 149
# rest_number 148
# rest_number 147
# rest_number 146
# rest_number 145
# rest_number 144
# rest_number 143
# rest_number 142
# rest_number 141
# rest_number 140
# rest_number 139
# rest_number 138
# rest_number 137
# rest_number 136
# rest_number 135
# rest_number 134
# rest_number 133
# rest_number 132
# rest_number 131
# rest_number 130
# rest_number 129
# rest_number 128
# rest_number 127
# rest_number 126
# rest_number 125
# rest_number 124
# rest_number 123
# rest_number 122
# rest_number 121
# rest_number 120
# rest_number 119
# rest_number 118
# rest_number 117
# rest_number 116
# rest_number 115
# rest_number 114
# rest_number 113
# rest_number 112
# rest_number 111
# rest_number 110
# rest_number 109
# rest_number 108
# rest_number 107
# rest_number 106
# rest_number 105
# rest_number 104
# rest_number 103
# rest_number 102
# rest_number 101
# rest_number 100
# rest_number 99
# rest_number 98
# rest_number 97
# rest_number 96
# rest_number 95
# rest_number 94
# rest_number 93
# rest_number 92
# rest_number 91
# rest_number 90
# rest_number 89
# rest_number 88
# rest_number 87
# rest_number 86
# rest_number 85
# rest_number 84
# rest_number 83
# rest_number 82
# rest_number 81
# rest_number 80
# rest_number 79
# rest_number 78
# rest_number 77
# rest_number 76
# rest_number 75
# rest_number 74
# rest_number 73
# rest_number 72
# rest_number 71
# rest_number 70
# rest_number 69
# rest_number 68
# rest_number 67
# rest_number 66
# rest_number 65
# rest_number 64
# rest_number 63
# rest_number 62
# rest_number 61
# rest_number 60
# rest_number 59
# rest_number 58
# rest_number 57
# rest_number 56
# rest_number 55
# rest_number 54
# rest_number 53
# rest_number 52
# rest_number 51
# rest_number 50
# rest_number 49
# rest_number 48
# rest_number 47
# rest_number 46
# rest_number 45
# rest_number 44
# rest_number 43
# rest_number 42
# rest_number 41
# rest_number 40
# rest_number 39
# rest_number 38
# rest_number 37
# rest_number 36
# rest_number 35
# rest_number 34
# rest_number 33
# rest_number 32
# rest_number 31
# rest_number 30
# rest_number 29
# rest_number 28
# rest_number 27
# rest_number 26
# rest_number 25
# rest_number 24
# rest_number 23
# rest_number 22
# rest_number 21
# rest_number 20
# rest_number 19
# rest_number 18
# rest_number 17
# rest_number 16
# rest_number 15
# rest_number 14
# rest_number 13
# rest_number 12
# rest_number 11
# rest_number 10
# rest_number 9
# rest_number 8
# rest_number 7
# rest_number 6
# rest_number 5
# rest_number 4
# rest_number 3
# rest_number 2
# rest_number 1
# in the beginning
# left number of pixel 100
# left number of pixel 10
# end, good job!, you are the best

# %%
plt.figure(1)
for sky_map in sky_map_list:
    hp.mollview(np.log10(np.transpose(sky_map)[1]), cmap = plt.cm.jet) # log10
    plt.savefig("mollview.eps", format='eps')
