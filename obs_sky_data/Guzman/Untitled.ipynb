# %%
import numpy as np
import healpy

# %%
data_fits.min()
# Out:
# -32768.0

# %%
abs(data_fits).min()
# Out:
# 3312.1477

# %%
data_fits.shape
# Out:
# (49152,)

# %%
data_fits = healpy.fitsfunc.read_map('MAIPU_MU_1_64.fits')
# healpy.mollview((np.log10(0.001+data_fits-data_fits.min())))
healpy.mollview(np.log10(data_fits))
# Out:
# /tmp/ipykernel_19940/4145458120.py:3: RuntimeWarning: invalid value encountered in log10
#   healpy.mollview(np.log10(data_fits))
